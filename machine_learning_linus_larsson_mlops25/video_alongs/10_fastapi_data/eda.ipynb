# %% [markdown]
# ## Eda

# %%
import pandas as pd

df = pd.read_csv("data/Sales.csv", parse_dates=True, index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 113036 entries, 2013-11-26 to 2016-03-04
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Day               113036 non-null  int64
#  1   Month             113036 non-null  object
#  2   Year              113036 non-null  int64
#  3   Customer_Age      113036 non-null  int64
#  4   Age_Group         113036 non-null  object
#  5   Customer_Gender   113036 non-null  object
#  6   Country           113036 non-null  object
#  7   State             113036 non-null  object
#  8   Product_Category  113036 non-null  object
#  9   Sub_Category      113036 non-null  object
#  10  Product           113036 non-null  object
#  11  Order_Quantity    113036 non-null  int64
#  12  Unit_Cost         113036 non-null  int64
#  13  Unit_Price        113036 non-null  int64
#  14  Profit            113036 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Day', 'Month', 'Year', 'Customer_Age', 'Age_Group', 'Customer_Gender',
#        'Country', 'State', 'Product_Category', 'Sub_Category', 'Product',
#        'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost',
#        'Revenue'],
#       dtype='object')

# %%
df = df.sort_index()
df.head()
# Out:
#             Day    Month  Year  Customer_Age             Age_Group  \
# Date
# 2011-01-01    1  January  2011            42        Adults (35-64)
# 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 2011-01-01    1  January  2011            17           Youth (<25)
# 2011-01-01    1  January  2011            39        Adults (35-64)
# 2011-01-01    1  January  2011            23           Youth (<25)
#
#            Customer_Gender        Country             State Product_Category  \
# Date
# 2011-01-01               M  United States        California            Bikes
# 2011-01-01               F         France           Yveline            Bikes
# 2011-01-01               M         Canada  British Columbia            Bikes
# 2011-01-01               M  United States        Washington            Bikes
# 2011-01-01               M      Australia          Victoria            Bikes
#
#               Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.loc["2014-01-20": "2014-01-21"].head()
# Out:
#             Day    Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2014-01-20   20  January  2014            23     Youth (<25)               M
# 2014-01-20   20  January  2014            50  Adults (35-64)               M
# 2014-01-20   20  January  2014            51  Adults (35-64)               M
# 2014-01-20   20  January  2014            46  Adults (35-64)               F
# 2014-01-20   20  January  2014            46  Adults (35-64)               F
#
#                   Country             State Product_Category  \
# Date
# 2014-01-20  United States        Washington            Bikes
# 2014-01-20         Canada  British Columbia         Clothing
# 2014-01-20  United States        Washington      Accessories
# 2014-01-20  United States        California      Accessories
# 2014-01-20  United States        California      Accessories
#
#                  Sub_Category                Product  Order_Quantity  \
# Date
# ...

# %%
df["State"].value_counts()
# Out:
# State
# California             22450
# British Columbia       14116
# England                13620
# Washington             11264
# New South Wales        10412
# Victoria                6016
# Oregon                  5286
# Queensland              5220
# Saarland                2770
# Nordrhein-Westfalen     2484
# Hessen                  2384
# Seine (Paris)           2328
# Hamburg                 1836
# Seine Saint Denis       1684
# Nord                    1670
# South Australia         1564
# Bayern                  1426
# Hauts de Seine          1084
# Essonne                  994
# Yveline                  954
# Tasmania                 724
# Seine et Marne           394
# Moselle                  386
# Loiret                   382
# Val d'Oise               264
# Garonne (Haute)          208
# Brandenburg              198
# Val de Marne             158
# Charente-Maritime        148
# Somme                    134
# Loir et Cher             120
# Pas de Calais             90
# ...

# %%
df["Product_Category"].unique()
# Out:
# array(['Bikes', 'Accessories', 'Clothing'], dtype=object)

# %%
df.query("Product_Category == 'Accessories'").head()
# Out:
#             Day Month  Year  Customer_Age             Age_Group  \
# Date
# 2013-07-01    1  July  2013            41        Adults (35-64)
# 2013-07-01    1  July  2013            41        Adults (35-64)
# 2013-07-01    1  July  2013            42        Adults (35-64)
# 2013-07-01    1  July  2013            28  Young Adults (25-34)
# 2013-07-01    1  July  2013            33  Young Adults (25-34)
#
#            Customer_Gender        Country              State Product_Category  \
# Date
# 2013-07-01               M        Germany             Hessen      Accessories
# 2013-07-01               M        Germany             Hessen      Accessories
# 2013-07-01               F         France  Seine Saint Denis      Accessories
# 2013-07-01               F      Australia    New South Wales      Accessories
# 2013-07-01               F  United States         Washington      Accessories
#
#                  Sub_Category                 Product  Order_Quantity  \
# Date
# ...

# %%
df["Country"].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
df["Country"].value_counts().to_json()
# Out:
# '{"United States":39206,"Australia":23936,"Canada":14178,"United Kingdom":13620,"Germany":11098,"France":10998}'

# %% [markdown]
# ## Profit per country

# %%
import duckdb

duckdb.query("""
    SELECT country, SUM(profit) as Profit
    FROM df
    GROUP BY country
    ORDER BY Profit DESC;
""").df().to_json()
# Out:
# '{"Country":{"0":"United States","1":"Australia","2":"United Kingdom","3":"Canada","4":"Germany","5":"France"},"Profit":{"0":11073644.0,"1":6776030.0,"2":4413853.0,"3":3717296.0,"4":3359995.0,"5":2880282.0}}'
